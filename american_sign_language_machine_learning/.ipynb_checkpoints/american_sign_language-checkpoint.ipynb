# %%
import math
import numpy as np
import glob as gb
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.io import imread
import os
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
import seaborn as sn
import time

# %%
print('Ilosc danych w bazie: 10 000')
print('Rozmiar obrazow w bazie: 400x400')

X = []
y = []

# dokonanie zmian w strukturze obrazow - skala szarosci oraz ujednolicenie rozmiaru
for folder in  os.listdir('./images') : 
    files = gb.glob(pathname= str('./images' + '/' + folder + '/*.jpg'))
    for file in files:
        image =  imread(file, as_gray=True)
        resized_image = resize(image, (100,100))
        X.append(resized_image)
        y.append(folder)
# Out:
# Ilosc danych w bazie: 10 000
# Rozmiar obrazow w bazie: 400x400

# %%
# podzial na zbior treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# przetestowanie zbioru treningowego
X_train, y_train = shuffle(X_train, y_train)

X_train = np.array(X_train)
X_test = np.array(X_test)

(unique_train, counts_train) = np.unique(y_train, return_counts=True)
frequencies_train = np.asarray((unique_train, counts_train*100/len(y_train))).T

(unique_test, counts_test) = np.unique(y_test, return_counts=True)
frequencies_test = np.asarray((unique_test, counts_test*100/len(y_test))).T

def bar_chart(l, s):
    labels = []
    data = []
    for i in l:
        labels.append(i[0])
        data.append(float(i[1]))
    plt.figure(figsize = (30,10))
    plt.pie(data, labels = labels, autopct='%1.2f%%')
    plt.title("Procetowy udział klas w zbiorze " + s, fontsize=20)
    plt.show()

# ustalenie procentowych udzialow poszczegolnych klas w zbiorze trningowym i testowym
bar_chart(frequencies_train, "treningowym")
bar_chart(frequencies_test, "testowym")

# ustalenie liczby klas i przydzielenie etykiet
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

labelsEncoded = {}
for i in range(0, 4):
    labelsEncoded[i] = le.inverse_transform([i])[0]
labelsEncoded
# Out:
# {0: 'A', 1: 'V', 2: 'W', 3: 'Z'}

# %%
# przygotowanie modelu sztucznej sieci neuronowej
model = Sequential()

model.add(Flatten(input_shape=(100, 100)))
model.add(Dense(128, activation='relu', name='fc1'))
model.add(Dense(64, activation='relu', name='fc2'))
model.add(Dense(4, activation='softmax', name='output'))

# kompilacja modelu z odpowiednia funkcja straty
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1)

# trenowanie modelu na zbiorze treningowym
history = model.fit(X_train, y_train, validation_split=0.33, epochs=10, callbacks=[tensorboard_callback])
result = model.evaluate(X_test, y_test)
predictions = model.predict(X_test)

# ocena modelu a zbiorze treningowym
print('\n\nStrata: ', result[0])
print('Dokladnosc: ', result[1])

# macierz bledu
y_labels = ['A', 'V', 'W', 'Z']
pred_labels = np.argmax(predictions, axis = 1)
m = metrics.confusion_matrix(y_test, pred_labels)
sn.heatmap(m, annot=True, fmt="d", cmap="YlGnBu", xticklabels=y_labels, yticklabels=y_labels)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 2s 9ms/step - loss: 1.0485 - accuracy: 0.5893 - val_loss: 0.5728 - val_accuracy: 0.7916
# Epoch 2/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.5540 - accuracy: 0.7703 - val_loss: 0.4681 - val_accuracy: 0.8241
# Epoch 3/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4427 - accuracy: 0.8264 - val_loss: 0.4026 - val_accuracy: 0.9127
# Epoch 4/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3725 - accuracy: 0.8572 - val_loss: 0.3221 - val_accuracy: 0.8495
# Epoch 5/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2722 - accuracy: 0.9071 - val_loss: 0.3051 - val_accuracy: 0.8531
# Epoch 6/10
# 141/141 [==============================] - 1s 8ms/step - loss: 0.2061 - accuracy: 0.9296 - val_loss: 0.1431 - val_accuracy: 0.9584
# Epoch 7/10
# 141/141 [==============================] - 1s 8ms/step - loss: 0.1398 - accuracy: 0.9537 - val_loss: 0.1146 - val_accuracy: 0.9589
# Epoch 8/10
# 141/141 [==============================] - 1s 8ms/step - loss: 0.1282 - accuracy: 0.9568 - val_loss: 0.1117 - val_accuracy: 0.9751
# Epoch 9/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1550 - accuracy: 0.9405 - val_loss: 0.7580 - val_accuracy: 0.7193
# Epoch 10/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1147 - accuracy: 0.9626 - val_loss: 0.1382 - val_accuracy: 0.9485
# 104/104 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9439
#
#
# Strata:  0.13742254674434662
# Dokladnosc:  0.9439393877983093
# <AxesSubplot:>

# %%
history.history['accuracy'] = np.array(history.history['accuracy'])*100
history.history['val_accuracy'] = np.array(history.history['val_accuracy'])*100

# wykres przedstawiajacy dokladnosc modelu na zbiorze treningowym i walidacyjnym w kolejnych epokach
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model dokladnosci')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# wykres przedstawiajacy strate modelu na zbiorze treningowym i walidacyjnym w kolejnych epokach
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model starty')
plt.ylabel('strata')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
    true_label, img = true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(labelsEncoded[predicted_label],
                                100*np.max(predictions_array),
                                labelsEncoded[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    true_label = true_label[i]
    plt.grid(False)
    plt.xticks(range(6))
    plt.yticks([])
    thisplot = plt.bar(range(len(predictions_array)), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')
    
    
# rozklady prawdopodobienstwa klas dla 100 przykladowych rekordow
num_rows = 20
num_cols = 5
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions[i], y_test, X_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.savefig('predictions')
plt.show()

# %%
# %load_ext tensorboard

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 4184), started 2:54:59 ago. (Use '!kill 4184' to kill it.)
#       <iframe id="tensorboard-frame-b690590f8413fc75" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b690590f8413fc75");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model_sigmoid = Sequential()
model_sigmoid.add(Flatten(input_shape=(100, 100)))
model_sigmoid.add(Dense(128, activation='sigmoid', name='fc1'))
model_sigmoid.add(Dense(64, activation='sigmoid', name='fc2'))
model_sigmoid.add(Dense(4, activation='softmax', name='output'))
model_sigmoid.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_sigmoid = model_sigmoid.fit(X_train, y_train, validation_split=0.33, epochs=10)
result_sigmoid = model_sigmoid.evaluate(X_test, y_test)

print('\n\nDokladnosc dla funkcji "sigmoid": ', result_sigmoid[1], '\n\n')


model_selu = Sequential()
model_selu.add(Flatten(input_shape=(100, 100)))
model_selu.add(Dense(128, activation='selu', name='fc1'))
model_selu.add(Dense(64, activation='selu', name='fc2'))
model_selu.add(Dense(4, activation='softmax', name='output'))
model_selu.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_selu = model_selu.fit(X_train, y_train, validation_split=0.33, epochs=10)
result_selu = model_selu.evaluate(X_test, y_test)

print('\n\nDokladnosc dla funkcji "selu": ', result_selu[1], '\n\n')


# porownanie dokladnosci roznych funkcji aktywacyjnych
history_selu.history['accuracy'] = np.array(history_selu.history['accuracy'])*100
history_sigmoid.history['accuracy'] = np.array(history_sigmoid.history['accuracy'])*100

plt.plot(history.history['accuracy'])
plt.plot(history_selu.history['accuracy'])
plt.plot(history_sigmoid.history['accuracy'])
plt.title('Porownanie dokladnosci roznych funkcji aktywacyjnych')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['relu', 'selu', 'sigmoid'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 141/141 [==============================] - 2s 9ms/step - loss: 1.4091 - accuracy: 0.2531 - val_loss: 1.4017 - val_accuracy: 0.2464
# Epoch 2/10
# 141/141 [==============================] - 1s 8ms/step - loss: 1.3952 - accuracy: 0.2500 - val_loss: 1.3898 - val_accuracy: 0.2392
# Epoch 3/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3920 - accuracy: 0.2496 - val_loss: 1.3940 - val_accuracy: 0.2464
# Epoch 4/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3938 - accuracy: 0.2415 - val_loss: 1.3884 - val_accuracy: 0.2613
# Epoch 5/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3893 - accuracy: 0.2549 - val_loss: 1.3875 - val_accuracy: 0.2464
# Epoch 6/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3904 - accuracy: 0.2484 - val_loss: 1.3888 - val_accuracy: 0.2613
# Epoch 7/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3902 - accuracy: 0.2431 - val_loss: 1.3901 - val_accuracy: 0.2532
# Epoch 8/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3895 - accuracy: 0.2536 - val_loss: 1.3907 - val_accuracy: 0.2613
# Epoch 9/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3896 - accuracy: 0.2440 - val_loss: 1.3929 - val_accuracy: 0.2392
# Epoch 10/10
# 141/141 [==============================] - 1s 7ms/step - loss: 1.3905 - accuracy: 0.2511 - val_loss: 1.3900 - val_accuracy: 0.2464
# 104/104 [==============================] - 0s 2ms/step - loss: 1.3889 - accuracy: 0.2485
#
#
# Dokladnosc dla funkcji "sigmoid":  0.24848484992980957
#
#
# Epoch 1/10
# 141/141 [==============================] - 1s 8ms/step - loss: 3.4143 - accuracy: 0.5704 - val_loss: 0.5430 - val_accuracy: 0.8332
# Epoch 2/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.5711 - accuracy: 0.7874 - val_loss: 0.6964 - val_accuracy: 0.6967
# Epoch 3/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4493 - accuracy: 0.8498 - val_loss: 0.3547 - val_accuracy: 0.9236
# Epoch 4/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3516 - accuracy: 0.9060 - val_loss: 0.3326 - val_accuracy: 0.9001
# Epoch 5/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3598 - accuracy: 0.8746 - val_loss: 0.5019 - val_accuracy: 0.7486
# Epoch 6/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2778 - accuracy: 0.9191 - val_loss: 0.2805 - val_accuracy: 0.9082
# Epoch 7/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2415 - accuracy: 0.9276 - val_loss: 0.1859 - val_accuracy: 0.9566
# Epoch 8/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1969 - accuracy: 0.9447 - val_loss: 0.1977 - val_accuracy: 0.9512
# Epoch 9/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2068 - accuracy: 0.9369 - val_loss: 0.1791 - val_accuracy: 0.9571
# Epoch 10/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1933 - accuracy: 0.9445 - val_loss: 0.1368 - val_accuracy: 0.9661
# 104/104 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9600
#
#
# Dokladnosc dla funkcji "selu":  0.9599999785423279

# %%
model_20 = Sequential()
model_20.add(Flatten(input_shape=(100, 100)))
model_20.add(Dense(128, activation='relu', name='fc1'))
model_20.add(Dense(64, activation='relu', name='fc2'))
model_20.add(Dense(4, activation='softmax', name='output'))
model_20.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_30 = Sequential()
model_30.add(Flatten(input_shape=(100, 100)))
model_30.add(Dense(128, activation='relu', name='fc1'))
model_30.add(Dense(64, activation='relu', name='fc2'))
model_30.add(Dense(4, activation='softmax', name='output'))
model_30.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_20 = model_20.fit(X_train, y_train, validation_split=0.33, epochs=20)
result_20 = model_20.evaluate(X_test, y_test)
print('\n\nDokladnosc dla 20 epok: ', result_20[1], '\n\n')

history_30 = model_30.fit(X_train, y_train, validation_split=0.33, epochs=30)
result_30 = model_30.evaluate(X_test, y_test)
print('\n\nDokladnosc dla 30 epok: ', result_30[1], '\n\n')


history_20.history['accuracy'] = np.array(history_20.history['accuracy'])*100
history_30.history['accuracy'] = np.array(history_30.history['accuracy'])*100

# porownanie dokladnosci roznej ilosci epok
plt.plot(history.history['accuracy'])
plt.plot(history_20.history['accuracy'])
plt.plot(history_30.history['accuracy'])
plt.title('Porownanie dokladnosci roznej ilosci epok')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['10', '20', '30'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 141/141 [==============================] - 2s 11ms/step - loss: 2.5556 - accuracy: 0.5334 - val_loss: 0.6988 - val_accuracy: 0.6953
# Epoch 2/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.6199 - accuracy: 0.7422 - val_loss: 0.5753 - val_accuracy: 0.8228
# Epoch 3/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4902 - accuracy: 0.8193 - val_loss: 0.4130 - val_accuracy: 0.9005
# Epoch 4/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4348 - accuracy: 0.8269 - val_loss: 0.4399 - val_accuracy: 0.7455
# Epoch 5/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3228 - accuracy: 0.8946 - val_loss: 0.3460 - val_accuracy: 0.8472
# Epoch 6/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2600 - accuracy: 0.9135 - val_loss: 0.2079 - val_accuracy: 0.9349
# Epoch 7/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1826 - accuracy: 0.9474 - val_loss: 0.1971 - val_accuracy: 0.9277
# Epoch 8/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1745 - accuracy: 0.9410 - val_loss: 0.1762 - val_accuracy: 0.9295
# Epoch 9/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1487 - accuracy: 0.9532 - val_loss: 0.1345 - val_accuracy: 0.9580
# Epoch 10/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1265 - accuracy: 0.9608 - val_loss: 0.1450 - val_accuracy: 0.9521
# Epoch 11/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1095 - accuracy: 0.9599 - val_loss: 0.0993 - val_accuracy: 0.9828
# Epoch 12/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0769 - accuracy: 0.9753 - val_loss: 0.0963 - val_accuracy: 0.9675
# Epoch 13/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0762 - accuracy: 0.9739 - val_loss: 0.0417 - val_accuracy: 0.9901
# Epoch 14/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.0851 - val_accuracy: 0.9806
# Epoch 15/20
# 141/141 [==============================] - 1s 8ms/step - loss: 0.0708 - accuracy: 0.9784 - val_loss: 0.0421 - val_accuracy: 0.9882
# Epoch 16/20
# 141/141 [==============================] - 1s 8ms/step - loss: 0.0409 - accuracy: 0.9893 - val_loss: 0.0334 - val_accuracy: 0.9914
# Epoch 17/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0406 - accuracy: 0.9891 - val_loss: 0.0327 - val_accuracy: 0.9901
# Epoch 18/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1017 - accuracy: 0.9646 - val_loss: 0.1125 - val_accuracy: 0.9512
# Epoch 19/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0954 - accuracy: 0.9672 - val_loss: 0.0527 - val_accuracy: 0.9806
# Epoch 20/20
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0532 - accuracy: 0.9811 - val_loss: 0.0334 - val_accuracy: 0.9910
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9903
#
#
# Dokladnosc dla 20 epok:  0.9903030395507812
#
#
# Epoch 1/30
# 141/141 [==============================] - 2s 9ms/step - loss: 2.5287 - accuracy: 0.5887 - val_loss: 0.6132 - val_accuracy: 0.7342
# Epoch 2/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.5711 - accuracy: 0.7803 - val_loss: 0.4649 - val_accuracy: 0.8874
# Epoch 3/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4693 - accuracy: 0.8405 - val_loss: 0.3982 - val_accuracy: 0.8549
# Epoch 4/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3829 - accuracy: 0.8795 - val_loss: 0.3168 - val_accuracy: 0.9159
# Epoch 5/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3219 - accuracy: 0.9060 - val_loss: 0.4314 - val_accuracy: 0.7939
# Epoch 6/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2799 - accuracy: 0.9129 - val_loss: 0.5641 - val_accuracy: 0.7423
# Epoch 7/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2775 - accuracy: 0.9037 - val_loss: 0.2191 - val_accuracy: 0.9462
# Epoch 8/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2403 - accuracy: 0.9227 - val_loss: 0.1815 - val_accuracy: 0.9561
# Epoch 9/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1705 - accuracy: 0.9557 - val_loss: 0.1428 - val_accuracy: 0.9643
# Epoch 10/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1630 - accuracy: 0.9521 - val_loss: 0.1511 - val_accuracy: 0.9543
# Epoch 11/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1441 - accuracy: 0.9563 - val_loss: 0.1758 - val_accuracy: 0.9426
# Epoch 12/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1209 - accuracy: 0.9597 - val_loss: 0.0939 - val_accuracy: 0.9729
# Epoch 13/30
# 141/141 [==============================] - 1s 6ms/step - loss: 0.1648 - accuracy: 0.9436 - val_loss: 0.1484 - val_accuracy: 0.9584
# Epoch 14/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1419 - accuracy: 0.9512 - val_loss: 0.2333 - val_accuracy: 0.8983
# Epoch 15/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1287 - accuracy: 0.9537 - val_loss: 0.1199 - val_accuracy: 0.9638
# Epoch 16/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0921 - accuracy: 0.9719 - val_loss: 0.0652 - val_accuracy: 0.9828
# Epoch 17/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1122 - accuracy: 0.9632 - val_loss: 0.0817 - val_accuracy: 0.9783
# Epoch 18/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0839 - accuracy: 0.9753 - val_loss: 0.0786 - val_accuracy: 0.9751
# Epoch 19/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1036 - accuracy: 0.9601 - val_loss: 0.1367 - val_accuracy: 0.9444
# Epoch 20/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0801 - accuracy: 0.9746 - val_loss: 0.0698 - val_accuracy: 0.9778
# Epoch 21/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0590 - accuracy: 0.9788 - val_loss: 0.0403 - val_accuracy: 0.9878
# Epoch 22/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0518 - accuracy: 0.9848 - val_loss: 0.0567 - val_accuracy: 0.9815
# Epoch 23/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0522 - accuracy: 0.9831 - val_loss: 0.0319 - val_accuracy: 0.9892
# Epoch 24/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0558 - accuracy: 0.9775 - val_loss: 0.0516 - val_accuracy: 0.9837
# Epoch 25/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0387 - accuracy: 0.9895 - val_loss: 0.0843 - val_accuracy: 0.9720
# Epoch 26/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0502 - accuracy: 0.9820 - val_loss: 0.0290 - val_accuracy: 0.9923
# Epoch 27/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0404 - accuracy: 0.9855 - val_loss: 0.0262 - val_accuracy: 0.9905
# Epoch 28/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0676 - accuracy: 0.9742 - val_loss: 0.0584 - val_accuracy: 0.9815
# Epoch 29/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0274 - val_accuracy: 0.9892
# Epoch 30/30
# 141/141 [==============================] - 1s 7ms/step - loss: 0.0355 - accuracy: 0.9866 - val_loss: 0.0346 - val_accuracy: 0.9919
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9918
#
#
# Dokladnosc dla 30 epok:  0.9918181896209717

# %%
model4 = Sequential()
model4.add(Flatten(input_shape=(100, 100)))
model4.add(Dense(64, activation='relu', name='fc1'))
model4.add(Dense(32, activation='relu', name='fc2'))
model4.add(Dense(4, activation='softmax', name='output'))
model4.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history4 = model4.fit(X_train, y_train, validation_split=0.33, epochs=10)
result4 = model4.evaluate(X_test, y_test)
print('\n\nDokladnosc dla 2x mniejszej ilosci neuronow: ', result4[1], '\n\n')

model5 = Sequential()
model5.add(Flatten(input_shape=(100, 100)))
model5.add(Dense(256, activation='relu', name='fc1'))
model5.add(Dense(128, activation='relu', name='fc2'))
model5.add(Dense(4, activation='softmax', name='output'))
model5.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history5 = model5.fit(X_train, y_train, validation_split=0.33, epochs=10)
result5 = model5.evaluate(X_test, y_test)
print('\n\nDokladnosc dla 2x wiekszej ilosci neuronow: ', result5[1], '\n\n')


history4.history['accuracy'] = np.array(history4.history['accuracy'])*100
history5.history['accuracy'] = np.array(history5.history['accuracy'])*100

# porownanie dokladnosci roznej ilosci neuronow
plt.plot(history.history['accuracy'])
plt.plot(history4.history['accuracy'])
plt.plot(history5.history['accuracy'])
plt.title('Porownanie dokladnosci roznej ilosci neuronow')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['podstawowa', '2x mniej', '2x wiecej'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 141/141 [==============================] - 1s 5ms/step - loss: 1.6875 - accuracy: 0.5771 - val_loss: 0.7155 - val_accuracy: 0.6921
# Epoch 2/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.5960 - accuracy: 0.7763 - val_loss: 0.7832 - val_accuracy: 0.6614
# Epoch 3/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.4724 - accuracy: 0.8436 - val_loss: 0.3805 - val_accuracy: 0.9308
# Epoch 4/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.4234 - accuracy: 0.8625 - val_loss: 0.3799 - val_accuracy: 0.8341
# Epoch 5/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.3348 - accuracy: 0.9022 - val_loss: 0.2592 - val_accuracy: 0.9340
# Epoch 6/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2904 - accuracy: 0.9118 - val_loss: 0.2361 - val_accuracy: 0.9444
# Epoch 7/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2637 - accuracy: 0.9209 - val_loss: 0.2538 - val_accuracy: 0.9204
# Epoch 8/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2883 - accuracy: 0.9053 - val_loss: 0.2093 - val_accuracy: 0.9390
# Epoch 9/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2212 - accuracy: 0.9372 - val_loss: 0.1885 - val_accuracy: 0.9571
# Epoch 10/10
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2082 - accuracy: 0.9414 - val_loss: 0.1689 - val_accuracy: 0.9543
# 104/104 [==============================] - 0s 1ms/step - loss: 0.1694 - accuracy: 0.9515
#
#
# Dokladnosc dla 2x mniejszej ilosci neuronow:  0.9515151381492615
#
#
# Epoch 1/10
# 141/141 [==============================] - 2s 13ms/step - loss: 2.5848 - accuracy: 0.5960 - val_loss: 0.5252 - val_accuracy: 0.8101
# Epoch 2/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.5004 - accuracy: 0.7832 - val_loss: 0.3810 - val_accuracy: 0.8680
# Epoch 3/10
# 141/141 [==============================] - 2s 11ms/step - loss: 0.3558 - accuracy: 0.8710 - val_loss: 0.2616 - val_accuracy: 0.9082
# Epoch 4/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.2621 - accuracy: 0.9049 - val_loss: 0.3456 - val_accuracy: 0.8350
# Epoch 5/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.2262 - accuracy: 0.9167 - val_loss: 0.2566 - val_accuracy: 0.9123
# Epoch 6/10
# 141/141 [==============================] - 2s 11ms/step - loss: 0.1833 - accuracy: 0.9372 - val_loss: 0.1197 - val_accuracy: 0.9684
# Epoch 7/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.1982 - accuracy: 0.9269 - val_loss: 0.1458 - val_accuracy: 0.9534
# Epoch 8/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.1447 - accuracy: 0.9488 - val_loss: 0.0851 - val_accuracy: 0.9738
# Epoch 9/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.1119 - accuracy: 0.9639 - val_loss: 0.1146 - val_accuracy: 0.9620
# Epoch 10/10
# 141/141 [==============================] - 2s 12ms/step - loss: 0.1220 - accuracy: 0.9537 - val_loss: 0.0797 - val_accuracy: 0.9751
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0840 - accuracy: 0.9697
#
#
# Dokladnosc dla 2x wiekszej ilosci neuronow:  0.9696969985961914

# %%
model6 = Sequential()
model6.add(Flatten(input_shape=(100, 100)))
model6.add(Dense(128, activation='relu', name='fc1'))
model6.add(Dense(96, activation='relu', name='fc2'))
model6.add(Dense(64, activation='relu', name='fc3'))
model6.add(Dense(32, activation='relu', name='fc4'))
model6.add(Dense(4, activation='softmax', name='output'))
model6.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history6 = model6.fit(X_train, y_train, validation_split=0.33, epochs=10)
result6 = model6.evaluate(X_test, y_test)
print('\n\nDokladnosc dla dodatkowych dwoch warstw: ', result6[1], '\n\n')


history6.history['accuracy'] = np.array(history6.history['accuracy'])*100

# porownanie dokladnosci z dodtkowymi warstwami ukrytymi
plt.plot(history.history['accuracy'])
plt.plot(history6.history['accuracy'])
plt.title('Porownanie dokladnosci miedzy 4 warstwami ukrytymi a 2')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['podstawowa', 'dodatkowe warstwy'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 141/141 [==============================] - 1s 8ms/step - loss: 1.4343 - accuracy: 0.5617 - val_loss: 0.7899 - val_accuracy: 0.5769
# Epoch 2/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.5839 - accuracy: 0.7582 - val_loss: 0.5168 - val_accuracy: 0.8020
# Epoch 3/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4690 - accuracy: 0.8260 - val_loss: 0.4529 - val_accuracy: 0.7844
# Epoch 4/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.4205 - accuracy: 0.8478 - val_loss: 0.3123 - val_accuracy: 0.9060
# Epoch 5/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.3297 - accuracy: 0.8888 - val_loss: 0.2192 - val_accuracy: 0.9521
# Epoch 6/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2819 - accuracy: 0.9055 - val_loss: 0.3118 - val_accuracy: 0.8684
# Epoch 7/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.2180 - accuracy: 0.9343 - val_loss: 0.1525 - val_accuracy: 0.9629
# Epoch 8/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1578 - accuracy: 0.9570 - val_loss: 0.1185 - val_accuracy: 0.9652
# Epoch 9/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1469 - accuracy: 0.9525 - val_loss: 0.0924 - val_accuracy: 0.9765
# Epoch 10/10
# 141/141 [==============================] - 1s 7ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.0752 - val_accuracy: 0.9760
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9736
#
#
# Dokladnosc dla dodatkowych dwoch warstw:  0.9736363887786865

# %%
# najlepszy model zwykly
model_best = Sequential()
model_best.add(Flatten(input_shape=(100, 100)))
model_best.add(Dense(192, activation='relu', name='fc1'))
model_best.add(Dense(96, activation='relu', name='fc2'))
model_best.add(Dense(4, activation='softmax', name='output'))
model_best.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

start_org = time.time()
history_best = model_best.fit(X_train, y_train, validation_split=0.33, epochs=30)
end_org  = time.time()
result_best = model_best.evaluate(X_test, y_test)
predictions_best = model_best.predict(X_test)

print('\n\nStrata: ', result_best[0])
print('Dokladnosc: ', result_best[1])

pred_labels_best = np.argmax(predictions_best, axis = 1)
m_best = metrics.confusion_matrix(y_test, pred_labels_best)
sn.heatmap(m_best, annot=True, fmt="d", cmap="YlGnBu", xticklabels=y_labels, yticklabels=y_labels)
# Out:
# Epoch 1/30
# 141/141 [==============================] - 2s 10ms/step - loss: 2.2239 - accuracy: 0.5481 - val_loss: 0.7181 - val_accuracy: 0.6659
# Epoch 2/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.6182 - accuracy: 0.7567 - val_loss: 0.4452 - val_accuracy: 0.7988
# Epoch 3/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.4465 - accuracy: 0.8253 - val_loss: 0.3533 - val_accuracy: 0.9200
# Epoch 4/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.3422 - accuracy: 0.8870 - val_loss: 0.2699 - val_accuracy: 0.9222
# Epoch 5/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.2497 - accuracy: 0.9207 - val_loss: 0.1987 - val_accuracy: 0.9430
# Epoch 6/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.2347 - accuracy: 0.9200 - val_loss: 0.3553 - val_accuracy: 0.8431
# Epoch 7/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1693 - accuracy: 0.9445 - val_loss: 0.1571 - val_accuracy: 0.9435
# Epoch 8/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1523 - accuracy: 0.9503 - val_loss: 0.1562 - val_accuracy: 0.9489
# Epoch 9/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1566 - accuracy: 0.9459 - val_loss: 0.1949 - val_accuracy: 0.9272
# Epoch 10/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1071 - accuracy: 0.9648 - val_loss: 0.0964 - val_accuracy: 0.9697
# Epoch 11/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0816 - accuracy: 0.9766 - val_loss: 0.0595 - val_accuracy: 0.9783
# Epoch 12/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0841 - accuracy: 0.9704 - val_loss: 0.1063 - val_accuracy: 0.9539
# Epoch 13/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1031 - accuracy: 0.9615 - val_loss: 0.0760 - val_accuracy: 0.9769
# Epoch 14/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0504 - accuracy: 0.9846 - val_loss: 0.1806 - val_accuracy: 0.9109
# Epoch 15/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0554 - accuracy: 0.9822 - val_loss: 0.0410 - val_accuracy: 0.9833
# Epoch 16/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0332 - accuracy: 0.9902 - val_loss: 0.0459 - val_accuracy: 0.9815
# Epoch 17/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.1570 - accuracy: 0.9577 - val_loss: 0.0361 - val_accuracy: 0.9892
# Epoch 18/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0590 - accuracy: 0.9782 - val_loss: 0.1872 - val_accuracy: 0.9222
# Epoch 19/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0527 - accuracy: 0.9824 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 20/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0260 - accuracy: 0.9929 - val_loss: 0.0626 - val_accuracy: 0.9765
# Epoch 21/30
# 141/141 [==============================] - 1s 11ms/step - loss: 0.0224 - accuracy: 0.9940 - val_loss: 0.0235 - val_accuracy: 0.9905
# Epoch 22/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0235 - accuracy: 0.9933 - val_loss: 0.0712 - val_accuracy: 0.9715
# Epoch 23/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.0234 - val_accuracy: 0.9923
# Epoch 24/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.0534 - val_accuracy: 0.9801
# Epoch 25/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0676 - accuracy: 0.9766 - val_loss: 0.0127 - val_accuracy: 0.9977
# Epoch 26/30
# 141/141 [==============================] - 1s 10ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.0098 - val_accuracy: 0.9982
# Epoch 27/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.0196 - val_accuracy: 0.9937
# Epoch 28/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.1250 - val_accuracy: 0.9530
# Epoch 29/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0323 - accuracy: 0.9898 - val_loss: 0.0177 - val_accuracy: 0.9955
# Epoch 30/30
# 141/141 [==============================] - 1s 9ms/step - loss: 0.0131 - accuracy: 0.9949 - val_loss: 0.0079 - val_accuracy: 0.9995
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9967
#
#
# Strata:  0.012230024673044682
# Dokladnosc:  0.996666669845581
# <AxesSubplot:>

# %%
history_best.history['accuracy'] = np.array(history_best.history['accuracy'])*100
history_best.history['val_accuracy'] = np.array(history_best.history['val_accuracy'])*100

plt.plot(history_best.history['accuracy'])
plt.plot(history_best.history['val_accuracy'])
plt.title('Model dokladnosci')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history_best.history['loss'])
plt.plot(history_best.history['val_loss'])
plt.title('Model starty')
plt.ylabel('strata')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# stworzenie modelu z warstwami konwolucyjnymi
X_train_conv = X_train.reshape(-1, 100, 100, 1)
X_test_conv = X_test.reshape(-1, 100, 100, 1)
y_train_conv = y_train.reshape(-1, 1)
y_test_conv = y_test.reshape(-1, 1)

model_conv = tf.keras.Sequential([
    tf.keras.layers.Conv2D(8, (3, 3), activation = 'relu', input_shape = (100, 100, 1)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(16, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation= 'relu'),
    tf.keras.layers.Dense(4, activation='softmax', name='output')
])

# %%
model_conv.compile(optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

start_conv = time.time()
history_conv = model_conv.fit(X_train_conv, y_train_conv, validation_split=0.33, epochs=5)
end_conv  = time.time()
result_conv = model_conv.evaluate(X_test_conv, y_test_conv)
predictions_conv = model_conv.predict(X_test_conv)

print('\n\nStrata: ', result_conv[0])
print('Dokladnosc: ', result_conv[1])

pred_labels_conv = np.argmax(predictions_conv, axis = 1)
m_conv = metrics.confusion_matrix(y_test_conv, pred_labels_conv)
sn.heatmap(m_conv, annot=True, fmt="d", cmap="YlGnBu", xticklabels=y_labels, yticklabels=y_labels)
# Out:
# Epoch 1/5
# 141/141 [==============================] - 7s 49ms/step - loss: 0.6874 - accuracy: 0.7139 - val_loss: 0.1404 - val_accuracy: 0.9675
# Epoch 2/5
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0514 - accuracy: 0.9893 - val_loss: 0.0135 - val_accuracy: 0.9995
# Epoch 3/5
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0085 - accuracy: 0.9998 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 4/5
# 141/141 [==============================] - 7s 48ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 5/5
# 141/141 [==============================] - 7s 49ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# 104/104 [==============================] - 1s 13ms/step - loss: 0.0019 - accuracy: 1.0000
#
#
# Strata:  0.0018873920198529959
# Dokladnosc:  1.0
# <AxesSubplot:>

# %%
history_conv.history['accuracy'] = np.array(history_conv.history['accuracy'])*100
history_conv.history['val_accuracy'] = np.array(history_conv.history['val_accuracy'])*100

plt.plot(history_conv.history['accuracy'])
plt.plot(history_conv.history['val_accuracy'])
plt.title('Model dokladnosci')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history_conv.history['loss'])
plt.plot(history_conv.history['val_loss'])
plt.title('Model starty')
plt.ylabel('strata')
plt.xlabel('epoka')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# porownanie czasow uczenia sie modeli
print("Czas modelu zwyklego: ", end_org - start_org)
print("Czas modelu konwolucyjnego: ", end_conv - start_conv)


# porownanie dokladnosci miedzy zwyklym modelem a modelem z warstwami konwolucyjnymi
plt.plot(history_best.history['accuracy'])
plt.plot(history_conv.history['accuracy'])
plt.title('Porownanie dokladnosci miedzy zwyklym modelem a modelem z warstwami konwolucyjnymi')
plt.ylabel('dokladnosc %')
plt.xlabel('epoka')
plt.legend(['zwykly', 'z warstwami konwolucyjnymi'], loc='upper right')
plt.show()

plt.plot(history_best.history['loss'])
plt.plot(history_conv.history['loss'])
plt.title('Porownanie straty miedzy zwyklym modelem a modelem z warstwami konwolucyjnymi')
plt.ylabel('strata')
plt.xlabel('epoka')
plt.legend(['zwykly', 'z warstwami konwolucyjnymi'], loc='upper right')
plt.show()

print('Strata modelu zwyklego: ', result_best[0])
print('Strata modelu z warstwami konwolucyjnymi: ', result_conv[0], '\n\n')

print('Dokladnoscmodelu zwyklego: ', result_best[1])
print('Dokladnosc modelu z warstwami konwolucyjnymi: ', result_conv[1])
# Out:
# Czas modelu zwyklego:  40.08899998664856
# Czas modelu konwolucyjnego:  34.61893677711487
# Strata modelu zwyklego:  0.012230024673044682
# Strata modelu z warstwami konwolucyjnymi:  0.0018873920198529959
#
#
# Dokladnoscmodelu zwyklego:  0.996666669845581
# Dokladnosc modelu z warstwami konwolucyjnymi:  1.0
